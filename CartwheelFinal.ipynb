# %% [markdown]
# #Read in nBody text file data from cartwheel group's final

# %%
import bonsai # my custom wrapper libraryimport tipsy # my custom .tipsy file utility

# %%
#convertheader = tipsy.txt2tipsy('initial/galaxies','initial/cartwheel_final.tipsy')

# %%
#test what we just convertedfrom IPython.core.display import Imagetest = tipsy.Stars('initial/cartwheel_final.tipsy')test.save_figure('test_final',lim=4,pointsize=.1,nRed=40000)Image(filename='test_final.png')
# Out:
# Loading Header (initial/cartwheel_final.tipsy)... time:0.000000, nTot:540000, nStar:540000

# %%
data_prefix = 'data/cartwheel_fin'figure_prefix = 'fig/cartwheel_fin'header

# %%
#run simulationimport mathbonsai.run_tipsy('initial/cartwheel_final.tipsy',data_prefix,T=40,dt=0.01,dSnap=.25,eps=.005)

# %%
#generate resultstipsy.read_tipsy(data_prefix,figure_prefix,lim=4,pointsize=.1,nRed=40000)

# %%
tipsy.make_mp4(figure_prefix,'cartwheel_fin',frame_rate=20)

# %%
#example of how to display video (from a file) in this ipython notebookimport io, base64from IPython.core.display import HTMLvideo = io.open('cartwheel_fin.mp4', 'r+b').read()encoded = base64.b64encode(video)HTML(data='''<video alt="test" controls loop>                <source src="data:video/mp4;base64,{0}" type="video/mp4" />             </video>'''.format(encoded.decode('ascii')))

# %%
#display video from internetHTML(data='''<video alt="test" controls loop>                <source src="https://googledrive.com/host/0By3y5bc79qIyU2c0WE4tQVFTZHM/bonsai/cartwheel_fin.mp4" type="video/mp4" />             </video>''')
# Out:
# <video alt="test" controls loop>                <source src="https://googledrive.com/host/0By3y5bc79qIyU2c0WE4tQVFTZHM/bonsai/cartwheel_fin.mp4" type="video/mp4" />             </video>

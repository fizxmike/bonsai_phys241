# %% [markdown]
# #Cartwheel CollisionMichael Folkerts<br/>UCSD Phys 241<br/>WI 2014 - Prof. Kuti

# %%
#my custom bonsai wrapper and tipsy librariesimport tipsyimport bonsai

# %%
#read in copy of bulgecollision = tipsy.Stars('initial/warm_ball.tipsy')print "Mass of ball %f" % sum(collision.mass)#move off centercollision.translate((0,0,-10.))#assign a velocitycollision.boost((0,0,1.0))#now add diskcollision.append('initial/warm_disk.tipsy')print "Mass of system: %f" % sum(collision.mass)#reset timestampcollision.time = 0.0#save a new tipsy filecollision.save_tipsy('initial/collision.tipsy')#save a figure of initial contidionscollision.save_figure('collision',lim=6,pointsize=.01)#,nRed=900000)#display initial conditionsfrom IPython.core.display import ImageImage(filename='collision.png')
# Out:
# Loading Header (initial/warm_ball.tipsy)... time:10.000411, nTot:200000, nStar:200000Mass of ball 0.431461
# Loading Header (initial/warm_disk.tipsy)... time:10.000411, nTot:810000, nStar:810000
# Mass of system: 6.344979
# Writing...Saved: initial/collision.tipsy

# %%
#settingsdata_prefix = 'data/collision_plummer'figure_prefix = 'fig/collision_plummer'mp4_prefix = 'collision_plummer't_max = 32dt = .001 #full res#dt = .05 #test resdSnap = 0.20 #snapshot intervalepsilon = 0.005#run simulationbonsai.run_tipsy('initial/collision.tipsy',data_prefix, T=t_max, dt=dt, dSnap=dSnap, eps = epsilon, mpi_n = 2)

# %%
#generate figurestipsy.read_tipsy(data_prefix,figure_prefix,lim=3,pointsize=.05)#,nRed=500000)

# %%
#generate movietipsy.make_mp4(figure_prefix,mp4_prefix,frame_rate=18)

# %%
#example of how to display video (from a file) in this ipython notebookimport io, base64from IPython.core.display import HTMLvideo = io.open(mp4_prefix+'.mp4', 'r+b').read()encoded = base64.b64encode(video)HTML(data='''<video alt="test" controls loop>                <source src="data:video/mp4;base64,{0}" type="video/mp4" />             </video>'''.format(encoded.decode('ascii')))

# %%
#display video from internetfrom IPython.core.display import HTMLHTML(data='''<video alt="test" controls loop>                <source src="https://googledrive.com/host/0By3y5bc79qIyU2c0WE4tQVFTZHM/bonsai/collision_plummer.mp4" type="video/mp4" />             </video>''')
# Out:
# <video alt="test" controls loop>                <source src="https://googledrive.com/host/0By3y5bc79qIyU2c0WE4tQVFTZHM/bonsai/collision_plummer.mp4" type="video/mp4" />             </video>

# %%
from IPython.core.display import Imagetimes = ['00003.2010','00009.0000','00011.6001','00013.8009']diskIDs = range(200000,900000)HTML=''for t in times:    snap = tipsy.Stars('data/collision_plummer_'+t)    snap.save_figure('collision_rings_'+t,lim=4,elevAng=90,pointsize=.1,IDs=diskIDs)
# Out:
# Loading Header (data/collision_plummer_00003.2010)... time:3.200950, nTot:1010000, nStar:1010000Loading Header (data/collision_plummer_00009.0000)... time:9.000007, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.6001)... time:11.600058, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.8009)... time:13.800947, nTot:1010000, nStar:1010000
# '<IPython.core.display.Image object at 0x3840d490><IPython.core.display.Image object at 0x5457d0d0><IPython.core.display.Image object at 0x3840d490><IPython.core.display.Image object at 0x5457d0d0>'

# %%
#generate disk only figures from top view:figure_prefix='collision_topview'diskIDs = range(200000,900000)tipsy.read_tipsy(data_prefix,figure_prefix,lim=4,pointsize=.1,elevAng=90,IDs=diskIDs)#,nRed=500000)
# Out:
# Loading Header (data/collision_plummer_00000.0000)... time:0.000000, nTot:1010000, nStar:1010000Loading Header (data/collision_plummer_00000.2000)... time:0.200000, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00000.4010)... time:0.400998, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00000.6010)... time:0.600996, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00000.8010)... time:0.800993, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00001.0010)... time:1.000991, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00001.2000)... time:1.200000, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00001.4000)... time:1.400009, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00001.6000)... time:1.600019, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00001.8000)... time:1.800028, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00002.0000)... time:2.000037, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00002.2000)... time:2.200023, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00002.4000)... time:2.400008, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00002.6010)... time:2.600994, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00002.8010)... time:2.800979, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00003.0010)... time:3.000965, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00003.2010)... time:3.200950, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00003.4009)... time:3.400936, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00003.6009)... time:3.600921, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00003.8009)... time:3.800907, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00004.0009)... time:4.000893, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00004.2009)... time:4.200878, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00004.4009)... time:4.400864, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00004.6008)... time:4.600849, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00004.8008)... time:4.800835, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00005.0008)... time:5.000820, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00005.2008)... time:5.200806, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00005.4008)... time:5.400791, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00005.6008)... time:5.600777, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00005.8008)... time:5.800762, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00006.0007)... time:6.000748, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00006.2007)... time:6.200733, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00006.4007)... time:6.400719, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00006.6007)... time:6.600704, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00006.8007)... time:6.800690, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00007.0007)... time:7.000675, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00007.2007)... time:7.200661, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00007.4006)... time:7.400646, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00007.6006)... time:7.600632, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00007.8006)... time:7.800617, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00008.0006)... time:8.000603, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00008.2007)... time:8.200684, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00008.4008)... time:8.400764, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00008.6008)... time:8.600845, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00008.8009)... time:8.800926, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00009.0000)... time:9.000007, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00009.2001)... time:9.200088, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00009.4002)... time:9.400168, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00009.6002)... time:9.600249, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00009.8003)... time:9.800330, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00010.0004)... time:10.000411, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00010.2005)... time:10.200492, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00010.4006)... time:10.400573, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00010.6007)... time:10.600654, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00010.8007)... time:10.800735, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.0008)... time:11.000815, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.2009)... time:11.200896, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.4010)... time:11.400977, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.6001)... time:11.600058, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00011.8001)... time:11.800138, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00012.0002)... time:12.000219, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00012.2003)... time:12.200300, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00012.4004)... time:12.400381, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00012.6005)... time:12.600462, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00012.8005)... time:12.800543, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.0006)... time:13.000624, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.2007)... time:13.200705, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.4008)... time:13.400785, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.6009)... time:13.600866, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00013.8009)... time:13.800947, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00014.0000)... time:14.000028, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00014.2001)... time:14.200109, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00014.4002)... time:14.400189, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00014.6003)... time:14.600270, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00014.8004)... time:14.800351, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00015.0004)... time:15.000432, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00015.2005)... time:15.200513, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00015.4006)... time:15.400594, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00015.6007)... time:15.600675, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00015.8008)... time:15.800756, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00016.0008)... time:16.000835, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00016.2007)... time:16.200726, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00016.4006)... time:16.400616, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00016.6005)... time:16.600506, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00016.8004)... time:16.800396, nTot:1010000, nStar:1010000
# Loading Header (data/collision_plummer_00017.0003)... time:17.000286, nTot:1010000, nStar:1010000

# %%
#generate moviemp4_prefix = 'collision_topview'tipsy.make_mp4(figure_prefix,mp4_prefix,frame_rate=18)

# %%
#example of how to display video (from a file) in this ipython notebookimport io, base64from IPython.core.display import HTMLvideo = io.open(mp4_prefix+'.mp4', 'r+b').read()encoded = base64.b64encode(video)HTML(data='''<video alt="test" controls loop>                <source src="data:video/mp4;base64,{0}" type="video/mp4" />             </video>'''.format(encoded.decode('ascii')))
# Out:
# Loading Header (data/collision_plummer_00011.6001)... time:11.600058, nTot:1010000, nStar:1010000

# %%
reload(tipsy)snap = tipsy.Stars('data/collision_plummer_00013.8009')snap.save_figure('collision_rings1',lim=4,elevAng=90,pointsize=.1,IDs=range(200000,900000))#display ringfrom IPython.core.display import ImageImage(filename='collision_rings1.png')
# Out:
# Loading Header (data/collision_plummer_00013.8009)... time:13.800947, nTot:1010000, nStar:1010000

# %%
#example of how to display video (from a file) in this ipython notebookimport io, base64from IPython.core.display import HTMLvideo = io.open(mp4_prefix+'.mp4', 'r+b').read()encoded = base64.b64encode(video)HTML(data='''<video alt="test" controls loop>                <source src="data:video/mp4;base64,{0}" type="video/mp4" />             </video>'''.format(encoded.decode('ascii')))

# %%
#set up python modules (be sure to do this first)import matplotlibmatplotlib.use('Agg')#parametersdata_prefix='data/plummer_snap_'

# %%
import bonsai#bonsai.run_plummer(10000,data_prefix)bonsai.run_sphere(1000,data_prefix)
# Out:
# 'Done'

# %%
import globglob.glob(data_prefix+"*")
# Out:
# ['data/plummer_snap__000001', 'data/plummer_snap__000000', 'data/plummer_snap__000002']

# %%
import bonsaisnaps = bonsai.load_tipsy(data_prefix)
# Out:
# Loading Header (data/plummer_snap__000001):Simulation Time: 1nTot: 1000, nDim: 3, nGas: 0, nDark: 0, nStar: 1000Loading Header (data/plummer_snap__000000):Simulation Time: 0nTot: 1000, nDim: 3, nGas: 0, nDark: 0, nStar: 1000Loading Header (data/plummer_snap__000002):Simulation Time: 2nTot: 1000, nDim: 3, nGas: 0, nDark: 0, nStar: 1000

# %%
from matplotlib import pyplot as pltimport numpy as npfrom mpl_toolkits.mplot3d import axes3ddata = snaps[2]['star'].posfig = plt.figure()ax = fig.gca(projection='3d')ax.plot(data[:,0],data[:,1],data[:,2],'o')plt.savefig('foo.png')

# %%
from IPython.core.display import Image Image(filename='foo.png')

# %%
#set up python modules (be sure to do this first)import matplotlibmatplotlib.use('Agg')from matplotlib import pyplot as pltimport numpy as npfrom mpl_toolkits.mplot3d import axes3dfrom IPython.core.display import Imageimport bonsai

# %% [markdown]
# #Sphere Model Simulation

# %%
reload(bonsai)step = 0.0625/10data_prefix='data/sphere_snap_mpi'bonsai.run_sphere(100000,data_prefix,dt=step,dSnap=step)snaps = bonsai.load_tipsy(data_prefix,'fig/')#saves fig only snaps will be empty
# Out:
# Loading Header (data/sphere_snap_mpi_00000.0000):Simulation Time: 0.000000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_0.png
# Loading Header (data/sphere_snap_mpi_00000.0063):Simulation Time: 0.006250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_1.png
# Loading Header (data/sphere_snap_mpi_00000.0125):Simulation Time: 0.012500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_2.png
# Loading Header (data/sphere_snap_mpi_00000.0156):Simulation Time: 0.015625nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_3.png
# Loading Header (data/sphere_snap_mpi_00000.0188):Simulation Time: 0.018750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_4.png
# Loading Header (data/sphere_snap_mpi_00000.0250):Simulation Time: 0.025000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_5.png
# Loading Header (data/sphere_snap_mpi_00000.0312):Simulation Time: 0.031250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_6.png
# Loading Header (data/sphere_snap_mpi_00000.0375):Simulation Time: 0.037500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_7.png
# Loading Header (data/sphere_snap_mpi_00000.0438):Simulation Time: 0.043750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_8.png
# Loading Header (data/sphere_snap_mpi_00000.0469):Simulation Time: 0.046875nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_9.png
# Loading Header (data/sphere_snap_mpi_00000.0500):Simulation Time: 0.050000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_10.png
# Loading Header (data/sphere_snap_mpi_00000.0563):Simulation Time: 0.056250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_11.png
# Loading Header (data/sphere_snap_mpi_00000.0625):Simulation Time: 0.062500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_12.png
# Loading Header (data/sphere_snap_mpi_00000.0688):Simulation Time: 0.068750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_13.png
# Loading Header (data/sphere_snap_mpi_00000.0750):Simulation Time: 0.075000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_14.png
# Loading Header (data/sphere_snap_mpi_00000.0781):Simulation Time: 0.078125nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_15.png
# Loading Header (data/sphere_snap_mpi_00000.0813):Simulation Time: 0.081250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_16.png
# Loading Header (data/sphere_snap_mpi_00000.0875):Simulation Time: 0.087500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_17.png
# Loading Header (data/sphere_snap_mpi_00000.0938):Simulation Time: 0.093750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_18.png
# Loading Header (data/sphere_snap_mpi_00000.1000):Simulation Time: 0.100000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_19.png
# Loading Header (data/sphere_snap_mpi_00000.1063):Simulation Time: 0.106250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_20.png
# Loading Header (data/sphere_snap_mpi_00000.1094):Simulation Time: 0.109375nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_21.png
# Loading Header (data/sphere_snap_mpi_00000.1125):Simulation Time: 0.112500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_22.png
# Loading Header (data/sphere_snap_mpi_00000.1188):Simulation Time: 0.118750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_23.png
# Loading Header (data/sphere_snap_mpi_00000.1250):Simulation Time: 0.125000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_24.png
# Loading Header (data/sphere_snap_mpi_00000.1313):Simulation Time: 0.131250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_25.png
# Loading Header (data/sphere_snap_mpi_00000.1375):Simulation Time: 0.137500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_26.png
# Loading Header (data/sphere_snap_mpi_00000.1406):Simulation Time: 0.140625nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_27.png
# Loading Header (data/sphere_snap_mpi_00000.1437):Simulation Time: 0.143750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_28.png
# Loading Header (data/sphere_snap_mpi_00000.1500):Simulation Time: 0.150000nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_29.png
# Loading Header (data/sphere_snap_mpi_00000.1562):Simulation Time: 0.156250nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_30.png
# Loading Header (data/sphere_snap_mpi_00000.1625):Simulation Time: 0.162500nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_31.png
# Loading Header (data/sphere_snap_mpi_00000.1687):Simulation Time: 0.168750nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_32.png
# Loading Header (data/sphere_snap_mpi_00000.1719):Simulation Time: 0.171875nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000fig/pos_33.png

# %%
reload(bonsai)bonsai.snap_figs(snaps,prefix='fig/')

# %%
# Out:
# <function lstrip>

# %% [markdown]
# ##Sphere Positions

# %%
pos = snaps[0]['star'].pos #positions(vel = snaps[0]['star'].vel #velocities

# %%
snaps[1]['time']
# Out:
# (2.0,)

# %%
lim = .8fig = plt.figure(figsize=(10,10))ax = fig.gca(projection='3d')ax.plot(pos[:,0],pos[:,1],pos[:,2],'w.',markersize=.75)ax.set_xlim(-lim,lim)ax.set_ylim(-lim,lim)ax.set_zlim(-lim,lim)ax.set_axis_off()ax.set_axis_bgcolor('black')plt.tight_layout()plt.savefig('pos.png')Image(filename='pos.png')

# %% [markdown]
# ##Sphere Velocities

# %%
lim = 5fig = plt.figure(figsize=(5,5))ax = fig.gca(projection='3d')ax.plot(vel[:,0],vel[:,1],vel[:,2],'.',markersize=.2)ax.set_xlim(-lim,lim)ax.set_ylim(-lim,lim)ax.set_zlim(-lim,lim)ax.set_axis_off()plt.tight_layout()plt.savefig('vel.png')Image(filename='vel.png')

# %% [markdown]
# #Sphere X-Coords.

# %%
plt.figure()plt.hist(pos[:,0],bins=1000)plt.xlim(-5,5)plt.savefig('histX1.png')Image(filename='histX1.png')

# %% [markdown]
# #Sphere Y Coords.

# %%
plt.figure()plt.hist(pos[:,1], bins=100)plt.xlim(-5,5)plt.savefig('histX2.png')Image(filename='histX2.png')

# %% [markdown]
# ##Sphere Z Coords.

# %%
plt.figure()plt.hist(pos[:,2], bins=100)plt.xlim(-5,5)plt.savefig('histX3.png')Image(filename='histX3.png')

# %% [markdown]
# ##Sphere Masses

# %%
from IPython.core.display import Imageplt.figure()mass = snaps[2]['star'].massplt.hist(mass[:],bins=100)plt.savefig('mass.png')Image(filename='mass.png')

# %% [markdown]
# #Plummer Model Simulation

# %%
data_prefix='data/plummer_snap_mpi'bonsai.run_plummer(100000,data_prefix)snaps = bonsai.load_tipsy(data_prefix)pos = snaps[1]['star'].pos #positionsvel = snaps[1]['star'].vel #velocities
# Out:
# Loading Header (data/plummer_snap_mpi_00001.0000):Simulation Time: 1nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000Loading Header (data/plummer_snap_mpi_00002.0000):
# Simulation Time: 2nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000Loading Header (data/plummer_snap_mpi_00000.0000):
# Simulation Time: 0nTot: 100000, nDim: 3, nGas: 0, nDark: 0, nStar: 100000

# %%
fig = plt.figure()ax = fig.gca(projection='3d')a3d = ax.plot(pos[:,0],pos[:,1],pos[:,2],'.',markersize=.2)ax.set_ylimax.set_xlim(-1,1)ax.set_ylim(-10,10)ax.set_zlim(-10,10)ax.set_title('Plummer Positions')plt.savefig('pos.png')Image(filename='pos.png')

# %%
fig = plt.figure()ax = fig.gca(projection='3d')a3d = ax.plot(vel[:,0],vel[:,1],vel[:,2],'.',markersize=.2)ax.set_ylimax.set_xlim(-10,10)ax.set_ylim(-2,2)ax.set_zlim(-2,2)ax.set_title('Plummer Velocities')plt.savefig('vel.png')Image(filename='vel.png')

# %%
plt.figure()plt.hist(pos[:,0], bins=100)plt.xlim(-2,2)plt.title('Plummer X Coords.')plt.savefig('histX2.png')Image(filename='histX2.png')

# %%
plt.figure()plt.hist(pos[:,1], bins=1000)plt.xlim(-5,5)plt.title('Plummer Y Coords.')plt.savefig('histX2.png')Image(filename='histX2.png')

# %%
plt.figure()plt.hist(pos[:,1], bins=1000)plt.xlim(-5,5)plt.title('Plummer Z Coords.')plt.savefig('histX2.png')Image(filename='histX2.png')
